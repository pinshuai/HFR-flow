# %% [markdown]
# # test problem

# %% [markdown]
# $z=x+y$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.plot(x,y, 'b')

# %%
# !jupyter nbconvert ./test.ipynb --to="script" --output="test-nbconvert"
# Out:
# [NbConvertApp] Converting notebook ./test.ipynb to script
# [NbConvertApp] Writing 274 bytes to ./test-nbconvert.py
