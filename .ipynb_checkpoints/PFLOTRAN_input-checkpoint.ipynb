# %% [markdown]
# # Generate PFLOTRAN input deck

# %%
setwd("/Users/shua784/Dropbox/PNNL/Projects/Reach_scale_model/")
paste("Working dir: ", getwd())
# Out:
# [1] "Working dir:  /Users/shua784/Dropbox/PNNL/Projects/Reach_scale_model"

# %%
imodel=c("200x200x5")

fname_material.h5.in = c("HFR_material_river.h5")
fname_H.initial.h5.in = c("HFR_H_Initial.h5")
fname_bc_dir = "bc_6h_smooth/"
fname.DatumH.in = c("DatumH_Mass1_")
fname.Gradient.in = c("Gradients_Mass1_")

fname_model_inputs.r = paste("results/model_inputs_", imodel, ".r", sep = "")

fname_pflotran.in = paste("Inputs/HFR_model_", imodel, "/pflotran_", imodel, "_6h_bc_nb.in", sep = "")

# %%
load(fname_model_inputs.r)
# print(fname_pflotran.in)

# %%
#-------------PARAMETERIZATION------------------#
start.time = as.POSIXct("2007-03-28 12:00:00",tz="GMT",format="%Y-%m-%d %H:%M:%S")
end.time = as.POSIXct("2016-01-01 00:00:00",tz="GMT",format="%Y-%m-%d %H:%M:%S")

grid.n_pts = c(nx, ny, nz)
grid.d_pts = c(idx,  idy,  idz)

river_cond = 4.65e-13 # from mean(rand_2) conductance

model_domain_origin = c(0,0,z0)

a = 0 #rotation
wall.stop = 19.8 # wallclock stop time, h
check.pt = 720 # check point, h

# solver
ts.acceleration = 8
max.ts.cuts = 50

diff.coeff = 1e-9 # diffusion coefficient
# recharge = 1.757e-9 #recharge rate 5.54 cm/yr from Fayer and Walters (1995)

##----------------------- material -------------------------------##
material.list = c("hanford", "cold_creek", "taylor_flats", "ringold_e", "ringold_lm", "ringold_a")
# material properties
Khf = 7000 #m/d from 300A model, William's 2008
hanford = list(ID = 1, porosity = 0.2, tortuosity = 1, perm.x = Khf/(9.5e11), perm.y = Khf/(9.5e11), perm.z = Khf/(9.5e12), cc = "cc1")
# Kcc = 4.8 #m/d from Last et al
Kcc = 100 #m/d from Paul's report
cold_creek = list(ID = 2, porosity = 0.25, tortuosity = 1, perm.x = Kcc/(9.5e11), perm.y = Kcc/(9.5e11), perm.z = Kcc/(9.5e12), cc = "cc1")
Ktf = 1 # m/d from franklin county report
taylor_flats = list(ID = 3, porosity = 0.43, tortuosity = 1, perm.x = Ktf/(9.5e11), perm.y = Ktf/(9.5e11), perm.z = Ktf/(9.5e12), cc = "cc2")
Kre = 40 # m/d from Paul's report
ringold_e = list(ID = 4, porosity = 0.25, tortuosity = 1, perm.x = Kre/(9.5e11), perm.y = Kre/(9.5e11), perm.z = Kre/(9.5e12), cc = "cc1")
Krlm = 1 #m/d from franklin
ringold_lm = list(ID = 5, porosity = 0.43, tortuosity = 1, perm.x = Krlm/(9.5e11), perm.y = Krlm/(9.5e11), perm.z = Krlm/(9.5e12), cc = "cc2")
Kra = 1 # similar to krlm
ringold_a = list(ID = 6, porosity = 0.43, tortuosity = 1, perm.x = Kra/(9.5e11), perm.y = Kra/(9.5e11), perm.z = Kra/(9.5e12), cc = "cc2")

K.list = list(hanford = hanford, cold_creek = cold_creek, taylor_flats = taylor_flats, ringold_e = ringold_e, ringold_lm = ringold_lm, ringold_a = ringold_a)
# saturation functions
cc.names = c("cc1", "cc2")

cc1 = list(M = 0.3391, alpha = 7.2727e-4, rsat = 0.16, max.cp = 1e8)
cc2 = list(M = 0.7479, alpha = 1.4319e-4, rsat = 0.1299, max.cp = 1e8)

cc.list = list(cc1 = cc1, cc2 = cc2)

# %%
# output opitons
output.ts = 120 # hour
h5.files = 73 # number of hdf5 files to write
obs.ts = 6 # hour

# %%
# --------------------------times----------------------------------
time.index = seq(from=start.time,to=end.time,by="1 hour")
ntime = length(time.index)
nhours = ntime # from 2010-02-27 12:00:00 to 2017-07-01 00:00:00
ini.ts = 0.01 #hour
max.ts = 6 #hour

# %%
##-----------------------flow region------------------------
slice.list = as.character(seq(40, 332, 1))
river_region = paste("Mass1_", slice.list, sep = "")
flow_region = paste("Flow_Mass1_", slice.list, sep = "")
names(river_region)  = flow_region
names(slice.list) = flow_region

# %%
## ------------------- add solute tracer----------------------------
solute.list = c("Solute_river")

## condition coupler, each flow region corresponds to one solute
solute.coupler.list = c(rep(solute.list, length(flow_region)))
names(solute.coupler.list)= flow_region

## concentration list should have same number as of solute list
concentration.list = c("Concentration_river")
names(concentration.list) = solute.list

## tracer list should has same num. of solute list
tracer.list = c("Tracer")
names(tracer.list) = concentration.list

## conductance assign same num. as of flow region
cond.list = c(rep(river_cond, length(flow_region)))

names(cond.list) = flow_region

# %%
## create river flow bc list

fname.river_datum = paste(fname.DatumH.in, slice.list, ".txt", sep = "")
fname.river_gradient = paste(fname.Gradient.in, slice.list, ".txt", sep = "")
names(fname.river_datum)= flow_region
names(fname.river_gradient)= flow_region

# datasets
flow.BC = c("Flow_West", "Flow_South", "Flow_North", "Flow_East")
BC.all = c("BC_East", "BC_West", "BC_South", "BC_North")
BC.list = c("BC_West", "BC_South", "BC_North", "BC_East")
BC.face = c("West", "South", "North", "East")
names(flow.BC) = BC.face
names(BC.list) = flow.BC
max.buff = 200

# %%
# model corner coordinates
xrange = c(0, xlen)
yrange = c(0, ylen)
zrange = c(z0, z0+zlen)

# %%
sink(fname_pflotran.in)
cat("## ===============BEGINNING of FILE=========================")
cat("\n")
cat("SIMULATION")
cat("\n")
cat("  SIMULATION_TYPE SUBSURFACE")
cat("\n")
cat("  PROCESS_MODELS")
cat("\n")
cat("  SUBSURFACE_FLOW flow")
cat("\n")
cat("  MODE RICHARDS")
cat("\n")
cat("  /")
cat("\n")
cat("  SUBSURFACE_TRANSPORT transport")
cat("\n")
cat("  GLOBAL_IMPLICIT")
cat("\n")
cat("  /")
cat("\n")
cat("/")
cat("\n")
cat("\n")
cat("\n")

cat("CHECKPOINT")
cat("\n")
cat(paste("  PERIODIC TIME"), check.pt, "h")
cat("\n")
cat("/")
cat("\n")
cat("\n")

cat("#  RESTART pflotran_bigplume-restart.chk")
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("SUBSURFACE")
cat("\n")
cat(paste("WALLCLOCK_STOP"), wall.stop, "h")
cat("\n")
cat("\n")
# Out:
# ## ===============BEGINNING of FILE=========================
# SIMULATION
#   SIMULATION_TYPE SUBSURFACE
#   PROCESS_MODELS
#   SUBSURFACE_FLOW flow
#   MODE RICHARDS
#   /
#   SUBSURFACE_TRANSPORT transport
#   GLOBAL_IMPLICIT
#   /
# /
#
#
# CHECKPOINT
#   PERIODIC TIME 720 h
# /
#
# #  RESTART pflotran_bigplume-restart.chk
# END
#
# SUBSURFACE
# WALLCLOCK_STOP 19.8 h

# %%
cat('#=======================chemistry========================')
cat("\n")
cat("CHEMISTRY")
cat("\n")
cat("  PRIMARY_SPECIES")
cat("\n")
for (itracer in tracer.list) {
  cat(paste("   ", itracer))
  cat("\n")
}
cat("    Tracer_Age")
cat("\n")
cat("  /")
cat("\n")
cat("  DATABASE tracer_HFR.dat")
cat("\n")
cat("  ACTIVITY_COEFFICIENTS OFF")
cat("\n")
cat("  OUTPUT")
cat("\n")
cat("    ALL")
cat("\n")
cat("    AGE")
cat("\n")
cat("    TOTAL")
cat("\n")
cat("/")
cat("\n")
cat("END")
cat("\n")
# Out:
# #=======================chemistry========================
# CHEMISTRY
#   PRIMARY_SPECIES
#     Tracer
#     Tracer_Age
#   /
#   DATABASE tracer_HFR.dat
#   ACTIVITY_COEFFICIENTS OFF
#   OUTPUT
#     ALL
#     AGE
#     TOTAL
# /
# END

# %%
cat('#=======================solver options========================')
cat("\n")
cat("TIMESTEPPER FLOW")
cat("\n")
cat(paste("  TS_ACCELERATION", ts.acceleration))
cat("\n")
cat(paste("  MAX_TS_CUTS", max.ts.cuts))
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("\n")
cat("TIMESTEPPER TRANSPORT")
cat("\n")
cat(paste("  TS_ACCELERATION", ts.acceleration))
cat("\n")
cat(paste("  MAX_TS_CUTS", max.ts.cuts))
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("NEWTON_SOLVER FLOW")
cat("\n")
cat("  MAXIT 20")
cat("\n")
cat("  RTOL 1.d-50")
cat("\n")
cat("  ATOL 1.d-50")
cat("\n")
cat("  STOL 1.d-60")
cat("\n")
cat("  ITOL_UPDATE 1.d0")
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("LINEAR_SOLVER FLOW")
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("NEWTON_SOLVER TRANSPORT")
cat("\n")
cat("  NO_INFINITY_NORM")
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("LINEAR_SOLVER TRANSPORT")
cat("\n")
cat("END")
cat("\n")
cat("\n")
# Out:
# #=======================solver options========================
# TIMESTEPPER FLOW
#   TS_ACCELERATION 8
#   MAX_TS_CUTS 50
# END
#
#
# TIMESTEPPER TRANSPORT
#   TS_ACCELERATION 8
#   MAX_TS_CUTS 50
# END
#
# NEWTON_SOLVER FLOW
#   MAXIT 20
#   RTOL 1.d-50
#   ATOL 1.d-50
#   STOL 1.d-60
#   ITOL_UPDATE 1.d0
# END
#
# LINEAR_SOLVER FLOW
# END
#
# NEWTON_SOLVER TRANSPORT
#   NO_INFINITY_NORM
# END
#
# LINEAR_SOLVER TRANSPORT
# END

# %%
cat('#=======================discretization========================')
cat("\n")
cat("GRID")
cat("\n")
cat("  TYPE structured")
cat("\n")
cat("  NXYZ ")
cat(grid.n_pts)
cat("\n")
cat("  ORIGIN ")
cat(model_domain_origin)
cat("\n")
cat("  DXYZ ")
# cat(grid.d_pts)
cat("\n")
cat("  ")
cat(grid.d_pts[1])
cat("\n")
cat("  ")
cat(grid.d_pts[2])
cat("\n")
cat("  ")
cat(grid.d_pts[3])
cat("\n")
cat("/")
cat("\n")
cat("  BOUNDS")
cat("\n")
cat("  ")
cat(xrange[1], yrange[1], zrange[1])
cat("\n")
cat("  ")
cat(xrange[2], yrange[2], zrange[2])
cat("\n")
cat("/")
cat("\n")
cat("END")
cat("\n")
# Out:
# #=======================discretization========================
# GRID
#   TYPE structured
#   NXYZ 300 300 40
#   ORIGIN 0 0 0
#   DXYZ
#   200
#   200
#   5
# /
#   BOUNDS
#   0 0 0
#   60000 60000 200
# /
# END

# %%
cat('#=======================fluid properties========================')
cat("\n")
cat("FLUID_PROPERTY")
cat("\n")
cat(paste("  DIFFUSION_COEFFICIENT", diff.coeff))
cat("\n")
cat("END")
cat("\n")
# Out:
# #=======================fluid properties========================
# FLUID_PROPERTY
#   DIFFUSION_COEFFICIENT 1e-09
# END

# %%
cat('#=======================datasets========================')
cat("\n")

# for (iBC in BC.all) {
#   cat(paste("DATASET", iBC))
#   cat("\n")
#   cat(paste("  FILENAME", fname_H.BC.h5))
#   cat("\n")
#   cat(paste("  HDF5_DATASET_NAME", iBC))
#   cat("\n")
#   cat(paste("  MAX_BUFFER_SIZE", max.buff))
#   cat("\n")
#   cat("END")
#   cat("\n")
#   cat("\n")
# }

cat("DATASET Initial_Head")
cat("\n")
cat(paste("  FILENAME", fname_H.initial.h5.in))
cat("\n")
cat("  HDF5_DATASET_NAME Initial_Head")
cat("\n")
cat("END")
cat("\n")

cat("\n")
# Out:
# #=======================datasets========================
# DATASET Initial_Head
#   FILENAME HFR_H_Initial.h5
#   HDF5_DATASET_NAME Initial_Head
# END

# %%
cat('#=======================material properties========================')
cat("\n")
for (imaterial in material.list) {
  
  cat(paste("MATERIAL_PROPERTY", imaterial))
  cat("\n")
  cat(paste("  ID"), K.list[[imaterial]]$ID)
  cat("\n")
  cat(paste("  POROSITY"), K.list[[imaterial]]$porosity)
  cat("\n")
  cat(paste("  TORTUOSITY"), K.list[[imaterial]]$tortuosity)
  cat("\n")
  cat(paste("  CHARACTERISTIC_CURVES", K.list[[imaterial]]$cc))
  cat("\n")
  cat("  PERMEABILITY")
  cat("\n")
  cat(paste("  PERM_X"), K.list[[imaterial]]$perm.x)
  cat("\n")
  cat(paste("  PERM_Y"), K.list[[imaterial]]$perm.y)
  cat("\n")
  cat(paste("  PERM_Z"), K.list[[imaterial]]$perm.z)
  cat("\n")
  cat('  /')
  cat("\n")
  cat('END')
  cat("\n")
  cat("\n")
  
}
# Out:
# #=======================material properties========================
# MATERIAL_PROPERTY hanford
#   ID 1
#   POROSITY 0.2
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc1
#   PERMEABILITY
#   PERM_X 7.368421e-09
#   PERM_Y 7.368421e-09
#   PERM_Z 7.368421e-10
#   /
# END
#
# MATERIAL_PROPERTY cold_creek
#   ID 2
#   POROSITY 0.25
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc1
#   PERMEABILITY
#   PERM_X 1.052632e-10
#   PERM_Y 1.052632e-10
#   PERM_Z 1.052632e-11
#   /
# END
#
# MATERIAL_PROPERTY taylor_flats
#   ID 3
#   POROSITY 0.43
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc2
#   PERMEABILITY
#   PERM_X 1.052632e-12
#   PERM_Y 1.052632e-12
#   PERM_Z 1.052632e-13
#   /
# END
#
# MATERIAL_PROPERTY ringold_e
#   ID 4
#   POROSITY 0.25
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc1
#   PERMEABILITY
#   PERM_X 4.210526e-11
#   PERM_Y 4.210526e-11
#   PERM_Z 4.210526e-12
#   /
# END
#
# MATERIAL_PROPERTY ringold_lm
#   ID 5
#   POROSITY 0.43
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc2
#   PERMEABILITY
#   PERM_X 1.052632e-12
#   PERM_Y 1.052632e-12
#   PERM_Z 1.052632e-13
#   /
# END
#
# MATERIAL_PROPERTY ringold_a
#   ID 6
#   POROSITY 0.43
#   TORTUOSITY 1
#   CHARACTERISTIC_CURVES cc2
#   PERMEABILITY
#   PERM_X 1.052632e-12
#   PERM_Y 1.052632e-12
#   PERM_Z 1.052632e-13
#   /
# END

# %%
cat('#=======================saturation fuctions========================')
cat("\n")
for (icc in cc.names) {
  
  cat(paste("CHARACTERISTIC_CURVES", icc))
  cat("\n")
  cat("  SATURATION_FUNCTION VAN_GENUCHTEN")
  cat("\n")
  cat(paste("    M"), cc.list[[icc]]$M)
  cat("\n")
  cat(paste("    ALPHA"), cc.list[[icc]]$alpha)
  cat("\n")
  cat(paste("    LIQUID_RESIDUAL_SATURATION"), cc.list[[icc]]$rsat)
  cat("\n")
  cat(paste("    MAX_CAPILLARY_PRESSURE"), cc.list[[icc]]$max.cp)
  cat("\n")
  cat('  /')
  cat("\n")
  cat("  PERMEABILITY_FUNCTION BURDINE_VG_LIQ")
  cat("\n")
  cat(paste("    M"), cc.list[[icc]]$M)
  cat("\n")
  cat(paste("    LIQUID_RESIDUAL_SATURATION"), cc.list[[icc]]$rsat)
  cat("\n")
  cat('  /')
  cat("\n")
  cat('END')
  cat("\n")
  cat("\n")
}
# Out:
# #=======================saturation fuctions========================
# CHARACTERISTIC_CURVES cc1
#   SATURATION_FUNCTION VAN_GENUCHTEN
#     M 0.3391
#     ALPHA 0.00072727
#     LIQUID_RESIDUAL_SATURATION 0.16
#     MAX_CAPILLARY_PRESSURE 1e+08
#   /
#   PERMEABILITY_FUNCTION BURDINE_VG_LIQ
#     M 0.3391
#     LIQUID_RESIDUAL_SATURATION 0.16
#   /
# END
#
# CHARACTERISTIC_CURVES cc2
#   SATURATION_FUNCTION VAN_GENUCHTEN
#     M 0.7479
#     ALPHA 0.00014319
#     LIQUID_RESIDUAL_SATURATION 0.1299
#     MAX_CAPILLARY_PRESSURE 1e+08
#   /
#   PERMEABILITY_FUNCTION BURDINE_VG_LIQ
#     M 0.7479
#     LIQUID_RESIDUAL_SATURATION 0.1299
#   /
# END

# %%
cat("\n")
cat('#=======================output options========================')
cat("\n")
cat("OUTPUT")
cat("\n")
cat("  SNAPSHOT_FILE")
cat("\n")
cat("  NO_PRINT_INITIAL")
cat("\n")
cat(paste("#  PERIODIC TIME"), output.ts, "h")
cat("\n")
cat("  PERIODIC TIME 5 day between 4 y and 9 y")
cat("\n")
cat(paste("#  FORMAT HDF5 MULTIPLE_FILES TIMES_PER_FILE"), h5.files)
cat("\n")
cat("  FORMAT HDF5 SINGLE_FILE")
cat("\n")
cat('  /')
cat("\n")
cat("\n")
cat("  MASS_BALANCE_FILE")
cat("\n")
cat("  NO_PRINT_INITIAL")
cat("\n")
cat(paste("#  PERIODIC TIME"), output.ts, "h")
cat("\n")
cat("  PERIODIC TIME 6 h between 4 y and 9 y")
cat("\n")
cat('  /')
cat("\n")
cat("\n")
cat("#  OBSERVATION_FILE")
cat("\n")
cat(paste("#  PERIODIC TIME"), obs.ts, "h")
cat("\n")
cat('#  /')
cat("\n")
cat("\n")
cat("#  VELOCITY_AT_CENTER ")
cat("\n")
cat("  VELOCITY_AT_FACE ")
cat("\n")
cat('END')
cat("\n")
cat("\n")
# Out:
# #=======================output options========================
# OUTPUT
#   SNAPSHOT_FILE
#   NO_PRINT_INITIAL
# #  PERIODIC TIME 120 h
#   PERIODIC TIME 5 day between 4 y and 9 y
# #  FORMAT HDF5 MULTIPLE_FILES TIMES_PER_FILE 73
#   FORMAT HDF5 SINGLE_FILE
#   /
#
#   MASS_BALANCE_FILE
#   NO_PRINT_INITIAL
# #  PERIODIC TIME 120 h
#   PERIODIC TIME 6 h between 4 y and 9 y
#   /
#
# #  OBSERVATION_FILE
# #  PERIODIC TIME 6 h
# #  /
#
# #  VELOCITY_AT_CENTER
#   VELOCITY_AT_FACE
# END

# %%
cat('#=======================times========================')
cat("\n")
cat("TIME")
cat("\n")
cat(paste("  FINAL_TIME", nhours, "h"))
cat("\n")
cat(paste("  INITIAL_TIMESTEP_SIZE", ini.ts, "h"))
cat("\n")
cat(paste("  MAXIMUM_TIMESTEP_SIZE", max.ts, "h"))
cat("\n")
cat('END')
cat("\n")
cat("\n")
# Out:
# #=======================times========================
# TIME
#   FINAL_TIME 76813 h
#   INITIAL_TIMESTEP_SIZE 0.01 h
#   MAXIMUM_TIMESTEP_SIZE 6 h
# END

# %%
cat('#=======================regions========================')
cat("\n")
cat('REGION all')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[1], zrange[1])
cat('\n')
cat("  ")
cat(xrange[2], yrange[2], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION Bottom')
cat('\n')
cat('FACE BOTTOM')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[1], zrange[1])
cat('\n')
cat("  ")
cat(xrange[2], yrange[2], zrange[1])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION Top')
cat('\n')
cat('FACE TOP')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[1], zrange[2])
cat('\n')
cat("  ")
cat(xrange[2], yrange[2], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION South')
cat('\n')
cat('FACE SOUTH')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[1], zrange[1])
cat('\n')
cat("  ")
cat(xrange[2], yrange[1], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION North')
cat('\n')
cat('FACE NORTH')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[2], zrange[1])
cat('\n')
cat("  ")
cat(xrange[2], yrange[2], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION West')
cat('\n')
cat('FACE WEST')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[1], yrange[1], zrange[1])
cat('\n')
cat("  ")
cat(xrange[1], yrange[2], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

cat('REGION East')
cat('\n')
cat('FACE EAST')
cat('\n')
cat('  COORDINATES')
cat('\n')
cat("  ")
cat(xrange[2], yrange[1], zrange[1])
cat('\n')
cat("  ")
cat(xrange[2], yrange[2], zrange[2])
cat('\n')
cat('  /')
cat('\n')
cat('END')
cat('\n')
cat('\n')

# cat('REGION Inj_Well')
# cat('\n')
# cat('  COORDINATES')
# cat('\n')
# cat(xx[inj_wellname], yy[inj_wellname], screen_bot[inj_wellname])
# cat('\n')
# cat(xx[inj_wellname], yy[inj_wellname], screen_top[inj_wellname])
# cat('\n')
# cat('  /')
# cat('\n')
# cat('/')
# cat('\n')

# %%%%%%%%%%%%%%%%%%%river regions%%%%%%%%%%%%%%%%%%%%%%%%%%

for (iriver in river_region) {
  cat(paste('REGION ', iriver, sep = '' ))
  cat('\n')
  cat(paste('  FILE ', fname_material.h5.in))
  cat('\n')
  cat('END')
  cat("\n")
  cat("\n")
}
cat("\n")

# #------------- %put observation wells in "regions" of input deck----------------------
# cat('# Observation wells')
# cat("\n")
# cat("\n")
# 
# for (iwell in well.list) {
#   
#   if (screen_top[iwell] >= z0 & screen_bot[iwell] <= z0+zlen) {
#   z = cells_z[which((cells_z >= screen_bot[iwell]) & (cells_z <= screen_top[iwell]))]
#   nz = length(z)
#   # wellname = rownames(Well)[iwell]
#     for (j in 1:nz) {
#       cat(paste('REGION ', iwell, '_', j, sep = ''))
#       cat('\n')
#       cat('  COORDINATE ');
#       cat(xx[iwell],yy[iwell], z[j])
#       cat('\n')
#       cat('/')
#       cat('\n')
#       cat('\n')
#     }
#   }
# }
# Out:
# #=======================regions========================
# REGION all
#   COORDINATES
#   0 0 0
#   60000 60000 200
#   /
# END
#
# REGION Bottom
# FACE BOTTOM
#   COORDINATES
#   0 0 0
#   60000 60000 0
#   /
# END
#
# REGION Top
# FACE TOP
#   COORDINATES
#   0 0 200
#   60000 60000 200
#   /
# END
#
# REGION South
# FACE SOUTH
#   COORDINATES
#   0 0 0
#   60000 0 200
#   /
# END
#
# REGION North
# FACE NORTH
#   COORDINATES
#   0 60000 0
#   60000 60000 200
#   /
# END
#
# REGION West
# FACE WEST
#   COORDINATES
#   0 0 0
#   0 60000 200
#   /
# END
#
# REGION East
# FACE EAST
#   COORDINATES
#   60000 0 0
#   60000 60000 200
#   /
# END
#
# REGION Mass1_40
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_41
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_42
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_43
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_44
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_45
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_46
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_47
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_48
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_49
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_50
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_51
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_52
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_53
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_54
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_55
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_56
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_57
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_58
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_59
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_60
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_61
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_62
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_63
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_64
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_65
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_66
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_67
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_68
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_69
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_70
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_71
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_72
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_73
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_74
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_75
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_76
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_77
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_78
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_79
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_80
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_81
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_82
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_83
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_84
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_85
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_86
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_87
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_88
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_89
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_90
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_91
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_92
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_93
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_94
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_95
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_96
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_97
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_98
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_99
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_100
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_101
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_102
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_103
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_104
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_105
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_106
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_107
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_108
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_109
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_110
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_111
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_112
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_113
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_114
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_115
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_116
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_117
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_118
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_119
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_120
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_121
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_122
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_123
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_124
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_125
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_126
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_127
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_128
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_129
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_130
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_131
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_132
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_133
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_134
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_135
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_136
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_137
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_138
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_139
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_140
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_141
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_142
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_143
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_144
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_145
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_146
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_147
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_148
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_149
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_150
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_151
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_152
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_153
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_154
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_155
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_156
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_157
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_158
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_159
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_160
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_161
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_162
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_163
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_164
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_165
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_166
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_167
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_168
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_169
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_170
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_171
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_172
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_173
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_174
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_175
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_176
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_177
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_178
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_179
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_180
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_181
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_182
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_183
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_184
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_185
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_186
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_187
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_188
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_189
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_190
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_191
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_192
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_193
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_194
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_195
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_196
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_197
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_198
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_199
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_200
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_201
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_202
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_203
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_204
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_205
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_206
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_207
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_208
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_209
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_210
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_211
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_212
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_213
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_214
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_215
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_216
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_217
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_218
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_219
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_220
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_221
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_222
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_223
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_224
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_225
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_226
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_227
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_228
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_229
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_230
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_231
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_232
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_233
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_234
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_235
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_236
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_237
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_238
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_239
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_240
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_241
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_242
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_243
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_244
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_245
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_246
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_247
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_248
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_249
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_250
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_251
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_252
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_253
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_254
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_255
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_256
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_257
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_258
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_259
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_260
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_261
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_262
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_263
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_264
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_265
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_266
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_267
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_268
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_269
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_270
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_271
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_272
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_273
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_274
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_275
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_276
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_277
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_278
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_279
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_280
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_281
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_282
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_283
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_284
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_285
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_286
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_287
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_288
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_289
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_290
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_291
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_292
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_293
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_294
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_295
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_296
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_297
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_298
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_299
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_300
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_301
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_302
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_303
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_304
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_305
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_306
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_307
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_308
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_309
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_310
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_311
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_312
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_313
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_314
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_315
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_316
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_317
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_318
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_319
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_320
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_321
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_322
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_323
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_324
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_325
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_326
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_327
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_328
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_329
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_330
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_331
#   FILE  HFR_material_river.h5
# END
#
# REGION Mass1_332
#   FILE  HFR_material_river.h5
# END

# %%
cat("#==================flow conditions=========================")
cat("\n")
cat("MINIMUM_HYDROSTATIC_PRESSURE -1.d0")
cat("\n")
cat("\n")

cat("FLOW_CONDITION Initial")
cat("\n")
cat("  TYPE")
cat("\n")
cat("    PRESSURE hydrostatic")
cat("\n")
cat('  /')
cat("\n")
cat("  CYCLIC")
cat("\n")
cat("  DATUM DATASET Initial_Head")
cat("\n")
cat("  PRESSURE 101325")
cat("\n")
cat("END")
cat("\n")
cat("\n")

# cat("FLOW_CONDITION Recharge")
# cat("\n")
# cat("  TYPE")
# cat("\n")
# cat("    FLUX neumann")
# cat("\n")
# cat('/')
# cat("\n")
# cat(paste("    FLUX"), recharge)
# cat("\n")
# cat('/')
# cat("\n")


#%%%%%%%%%%%%%%%%%%%% river regions %%%%%%%%%%%%%%%%%%%%%%%%%
for (iflow in flow_region) {
  cat(paste("FLOW_CONDITION"), iflow)
  cat("\n")
  cat("  TYPE")
  cat("\n")
  cat("  PRESSURE conductance")
  cat("\n")
  cat('  /')
  cat("\n")
  cat(paste("  CONDUCTANCE"), cond.list[iflow])
  cat("\n")
  cat("  CYCLIC")
  cat("\n")
  cat(paste("  DATUM file ", fname_bc_dir, fname.river_datum[iflow], sep = ""))
  cat("\n")
  cat("  PRESSURE 101325")
  cat("\n")
  cat("  GRADIENT")
  cat("\n")
  cat(paste("  PRESSURE file ",fname_bc_dir, fname.river_gradient[iflow], sep = ""))
  cat("\n")
  cat('  /')
  cat("\n")
  cat('/')
  cat("\n")
  cat("\n")
}

# ## flow BCs
# for (iflow.BC in flow.BC) {
#   cat(paste("FLOW_CONDITION"), iflow.BC)
#   cat("\n")
#   cat("  TYPE")
#   cat("\n")
#   cat("  PRESSURE hydrostatic")
#   cat("\n")
#   cat("  /")
#   cat("\n")
#   cat("  CYCLIC")
#   cat("\n")
#   cat(paste("  DATUM DATASET"), BC.list[iflow.BC])
#   cat("\n")
#   cat("  PRESSURE 101325")
#   cat("\n")
#   cat("/")
#   cat("\n")
#   cat("\n")
# }
# Out:
# #==================flow conditions=========================
# MINIMUM_HYDROSTATIC_PRESSURE -1.d0
#
# FLOW_CONDITION Initial
#   TYPE
#     PRESSURE hydrostatic
#   /
#   CYCLIC
#   DATUM DATASET Initial_Head
#   PRESSURE 101325
# END
#
# FLOW_CONDITION Flow_Mass1_40
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_40.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_40.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_41
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_41.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_41.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_42
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_42.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_42.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_43
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_43.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_43.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_44
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_44.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_44.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_45
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_45.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_45.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_46
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_46.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_46.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_47
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_47.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_47.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_48
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_48.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_48.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_49
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_49.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_49.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_50
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_50.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_50.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_51
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_51.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_51.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_52
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_52.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_52.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_53
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_53.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_53.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_54
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_54.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_54.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_55
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_55.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_55.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_56
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_56.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_56.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_57
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_57.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_57.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_58
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_58.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_58.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_59
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_59.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_59.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_60
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_60.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_60.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_61
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_61.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_61.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_62
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_62.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_62.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_63
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_63.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_63.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_64
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_64.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_64.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_65
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_65.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_65.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_66
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_66.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_66.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_67
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_67.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_67.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_68
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_68.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_68.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_69
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_69.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_69.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_70
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_70.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_70.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_71
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_71.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_71.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_72
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_72.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_72.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_73
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_73.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_73.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_74
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_74.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_74.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_75
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_75.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_75.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_76
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_76.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_76.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_77
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_77.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_77.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_78
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_78.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_78.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_79
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_79.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_79.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_80
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_80.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_80.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_81
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_81.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_81.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_82
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_82.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_82.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_83
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_83.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_83.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_84
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_84.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_84.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_85
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_85.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_85.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_86
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_86.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_86.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_87
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_87.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_87.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_88
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_88.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_88.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_89
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_89.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_89.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_90
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_90.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_90.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_91
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_91.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_91.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_92
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_92.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_92.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_93
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_93.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_93.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_94
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_94.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_94.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_95
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_95.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_95.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_96
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_96.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_96.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_97
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_97.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_97.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_98
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_98.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_98.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_99
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_99.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_99.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_100
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_100.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_100.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_101
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_101.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_101.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_102
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_102.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_102.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_103
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_103.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_103.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_104
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_104.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_104.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_105
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_105.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_105.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_106
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_106.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_106.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_107
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_107.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_107.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_108
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_108.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_108.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_109
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_109.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_109.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_110
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_110.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_110.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_111
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_111.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_111.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_112
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_112.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_112.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_113
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_113.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_113.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_114
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_114.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_114.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_115
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_115.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_115.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_116
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_116.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_116.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_117
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_117.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_117.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_118
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_118.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_118.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_119
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_119.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_119.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_120
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_120.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_120.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_121
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_121.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_121.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_122
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_122.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_122.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_123
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_123.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_123.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_124
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_124.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_124.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_125
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_125.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_125.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_126
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_126.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_126.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_127
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_127.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_127.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_128
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_128.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_128.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_129
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_129.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_129.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_130
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_130.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_130.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_131
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_131.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_131.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_132
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_132.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_132.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_133
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_133.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_133.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_134
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_134.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_134.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_135
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_135.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_135.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_136
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_136.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_136.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_137
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_137.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_137.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_138
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_138.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_138.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_139
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_139.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_139.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_140
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_140.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_140.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_141
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_141.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_141.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_142
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_142.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_142.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_143
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_143.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_143.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_144
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_144.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_144.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_145
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_145.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_145.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_146
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_146.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_146.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_147
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_147.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_147.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_148
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_148.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_148.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_149
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_149.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_149.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_150
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_150.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_150.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_151
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_151.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_151.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_152
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_152.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_152.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_153
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_153.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_153.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_154
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_154.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_154.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_155
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_155.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_155.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_156
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_156.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_156.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_157
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_157.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_157.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_158
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_158.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_158.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_159
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_159.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_159.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_160
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_160.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_160.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_161
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_161.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_161.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_162
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_162.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_162.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_163
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_163.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_163.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_164
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_164.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_164.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_165
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_165.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_165.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_166
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_166.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_166.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_167
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_167.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_167.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_168
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_168.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_168.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_169
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_169.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_169.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_170
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_170.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_170.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_171
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_171.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_171.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_172
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_172.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_172.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_173
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_173.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_173.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_174
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_174.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_174.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_175
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_175.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_175.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_176
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_176.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_176.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_177
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_177.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_177.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_178
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_178.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_178.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_179
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_179.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_179.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_180
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_180.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_180.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_181
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_181.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_181.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_182
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_182.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_182.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_183
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_183.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_183.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_184
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_184.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_184.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_185
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_185.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_185.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_186
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_186.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_186.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_187
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_187.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_187.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_188
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_188.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_188.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_189
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_189.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_189.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_190
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_190.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_190.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_191
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_191.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_191.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_192
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_192.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_192.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_193
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_193.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_193.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_194
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_194.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_194.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_195
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_195.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_195.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_196
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_196.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_196.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_197
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_197.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_197.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_198
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_198.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_198.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_199
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_199.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_199.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_200
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_200.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_200.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_201
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_201.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_201.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_202
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_202.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_202.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_203
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_203.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_203.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_204
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_204.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_204.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_205
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_205.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_205.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_206
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_206.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_206.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_207
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_207.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_207.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_208
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_208.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_208.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_209
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_209.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_209.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_210
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_210.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_210.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_211
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_211.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_211.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_212
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_212.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_212.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_213
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_213.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_213.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_214
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_214.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_214.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_215
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_215.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_215.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_216
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_216.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_216.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_217
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_217.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_217.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_218
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_218.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_218.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_219
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_219.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_219.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_220
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_220.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_220.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_221
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_221.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_221.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_222
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_222.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_222.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_223
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_223.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_223.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_224
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_224.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_224.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_225
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_225.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_225.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_226
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_226.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_226.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_227
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_227.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_227.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_228
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_228.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_228.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_229
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_229.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_229.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_230
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_230.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_230.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_231
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_231.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_231.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_232
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_232.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_232.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_233
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_233.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_233.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_234
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_234.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_234.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_235
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_235.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_235.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_236
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_236.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_236.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_237
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_237.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_237.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_238
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_238.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_238.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_239
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_239.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_239.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_240
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_240.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_240.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_241
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_241.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_241.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_242
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_242.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_242.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_243
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_243.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_243.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_244
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_244.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_244.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_245
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_245.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_245.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_246
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_246.txt
#   PRESSURE 101325
#   GRADIENT
# ...
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_264.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_264.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_265
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_265.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_265.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_266
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_266.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_266.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_267
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_267.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_267.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_268
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_268.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_268.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_269
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_269.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_269.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_270
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_270.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_270.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_271
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_271.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_271.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_272
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_272.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_272.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_273
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_273.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_273.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_274
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_274.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_274.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_275
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_275.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_275.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_276
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_276.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_276.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_277
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_277.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_277.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_278
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_278.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_278.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_279
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_279.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_279.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_280
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_280.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_280.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_281
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_281.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_281.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_282
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_282.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_282.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_283
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_283.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_283.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_284
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_284.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_284.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_285
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_285.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_285.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_286
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_286.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_286.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_287
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_287.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_287.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_288
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_288.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_288.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_289
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_289.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_289.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_290
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_290.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_290.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_291
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_291.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_291.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_292
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_292.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_292.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_293
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_293.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_293.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_294
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_294.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_294.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_295
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_295.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_295.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_296
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_296.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_296.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_297
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_297.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_297.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_298
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_298.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_298.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_299
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_299.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_299.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_300
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_300.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_300.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_301
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_301.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_301.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_302
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_302.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_302.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_303
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_303.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_303.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_304
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_304.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_304.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_305
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_305.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_305.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_306
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_306.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_306.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_307
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_307.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_307.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_308
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_308.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_308.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_309
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_309.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_309.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_310
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_310.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_310.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_311
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_311.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_311.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_312
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_312.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_312.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_313
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_313.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_313.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_314
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_314.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_314.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_315
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_315.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_315.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_316
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_316.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_316.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_317
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_317.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_317.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_318
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_318.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_318.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_319
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_319.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_319.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_320
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_320.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_320.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_321
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_321.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_321.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_322
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_322.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_322.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_323
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_323.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_323.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_324
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_324.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_324.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_325
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_325.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_325.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_326
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_326.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_326.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_327
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_327.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_327.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_328
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_328.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_328.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_329
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_329.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_329.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_330
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_330.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_330.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_331
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_331.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_331.txt
#   /
# /
#
# FLOW_CONDITION Flow_Mass1_332
#   TYPE
#   PRESSURE conductance
#   /
#   CONDUCTANCE 4.65e-13
#   CYCLIC
#   DATUM file bc_6h_smooth/DatumH_Mass1_332.txt
#   PRESSURE 101325
#   GRADIENT
#   PRESSURE file bc_6h_smooth/Gradients_Mass1_332.txt
#   /
# /

# %%
cat("#==================transport conditions=========================")
cat("\n")
cat("TRANSPORT_CONDITION Initial")
cat("\n")
cat("  TYPE dirichlet_zero_gradient")
cat("\n")
cat("  CONSTRAINT_LIST")
cat("\n")
cat("  ")
cat(paste(0, "Concentration_initial"))
cat("\n")
cat("/")
cat("\n")
cat("END")
cat("\n")

for (isolute in solute.list) {
  cat(paste("TRANSPORT_CONDITION"), isolute)
  cat("\n")
  cat("  TYPE dirichlet")
  cat("\n")
  cat("  CONSTRAINT_LIST")
  cat("\n")
  cat("  ")
  cat(paste(0, concentration.list[isolute]))
  cat("\n")
  cat("/")
  cat("\n")
  cat("END")
  cat("\n")
}
# Out:
# #==================transport conditions=========================
# TRANSPORT_CONDITION Initial
#   TYPE dirichlet_zero_gradient
#   CONSTRAINT_LIST
#   0 Concentration_initial
# /
# END
# TRANSPORT_CONDITION Solute_river
#   TYPE dirichlet
#   CONSTRAINT_LIST
#   0 Concentration_river
# /
# END

# %%
# sink()
cat("#==================constraints=========================")
cat("\n")
for (iconc in concentration.list) {
  cat(paste("CONSTRAINT", iconc))
  cat("\n")
  cat("  CONCENTRATIONS")
  cat("\n")
  for (itracer in tracer.list) {
    if (itracer == tracer.list[iconc]) {
      cat("   ")
      cat(paste(itracer), "1.d0 T")
    } else {
      cat("   ")
      cat(paste(itracer), "1.d-20 T")
    }
    cat("\n")

  }
  cat("    Tracer_Age  1.d-20 T")
  cat("\n")  
  cat("  /")
  cat("\n")
  cat("END")
  cat("\n")
  cat("\n")
}

cat("\n")
cat("CONSTRAINT Concentration_initial")
cat("\n")
cat("  CONCENTRATIONS")
cat("\n")
for (itracer in tracer.list) {
  cat("   ")
  cat(paste(itracer), "1.d-20 T")
  cat("\n")
}
cat("    Tracer_Age  1.d-20 T")
cat("\n")  
cat("  /")
cat("\n")
cat("END")
cat("\n")
cat("\n")

cat("\n")
# Out:
# #==================constraints=========================
# CONSTRAINT Concentration_river
#   CONCENTRATIONS
#    Tracer 1.d0 T
#     Tracer_Age  1.d-20 T
#   /
# END
#
#
# CONSTRAINT Concentration_initial
#   CONCENTRATIONS
#    Tracer 1.d-20 T
#     Tracer_Age  1.d-20 T
#   /
# END

# %%
cat("#==================condition couplers=========================")
# 
cat("\n")
cat("INITIAL_CONDITION")
cat("\n")
cat("  FLOW_CONDITION Initial")
cat("\n")
cat("  TRANSPORT_CONDITION Initial")
cat("\n")
cat("  REGION all")
cat("\n")
cat("END")
cat("\n")
cat("\n")

#%%%%%%%%%%%%%%%%%%%%% River BC coupling %%%%%%%%%%%%%%%%%%%%%%%%%%
for (iflow in flow_region) {
  cat(paste("BOUNDARY_CONDITION River_", slice.list[iflow], sep = ""))
  cat("\n")
  cat(paste("  FLOW_CONDITION"), iflow)
  cat("\n")
  cat(paste("  TRANSPORT_CONDITION"), solute.coupler.list[iflow])
  cat("\n")
  cat(paste("  REGION"), river_region[iflow])
  cat("\n")
  cat("END")
  cat("\n")
  cat("\n")
}

# for (iface in BC.face) {
#   cat(paste("BOUNDARY_CONDITION", iface))
#   cat("\n")
#   cat(paste("  FLOW_CONDITION", flow.BC[iface]))
#   cat("\n")
#   if (iface == "North") {
#     cat(paste("  TRANSPORT_CONDITION", solute.list[5]))
#   } else {
#     cat("  TRANSPORT_CONDITION Initial")
#   }
#   cat("\n")
#   cat(paste("  REGION"), iface) 
#   cat("\n")
#   cat("END")
#   cat("\n")
#   cat("\n")
# }

# for (iface in BC.face) {
#   cat(paste("BOUNDARY_CONDITION", iface))
#   cat("\n")
#   cat(paste("  FLOW_CONDITION", flow.BC[iface]))
#   cat("\n")
#     cat("  TRANSPORT_CONDITION Initial")
#   cat("\n")
#   cat(paste("  REGION"), iface)
#   cat("\n")
#   cat("END")
#   cat("\n")
#   cat("\n")
# }
# Out:
# #==================condition couplers=========================
# INITIAL_CONDITION
#   FLOW_CONDITION Initial
#   TRANSPORT_CONDITION Initial
#   REGION all
# END
#
# BOUNDARY_CONDITION River_40
#   FLOW_CONDITION Flow_Mass1_40
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_40
# END
#
# BOUNDARY_CONDITION River_41
#   FLOW_CONDITION Flow_Mass1_41
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_41
# END
#
# BOUNDARY_CONDITION River_42
#   FLOW_CONDITION Flow_Mass1_42
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_42
# END
#
# BOUNDARY_CONDITION River_43
#   FLOW_CONDITION Flow_Mass1_43
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_43
# END
#
# BOUNDARY_CONDITION River_44
#   FLOW_CONDITION Flow_Mass1_44
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_44
# END
#
# BOUNDARY_CONDITION River_45
#   FLOW_CONDITION Flow_Mass1_45
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_45
# END
#
# BOUNDARY_CONDITION River_46
#   FLOW_CONDITION Flow_Mass1_46
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_46
# END
#
# BOUNDARY_CONDITION River_47
#   FLOW_CONDITION Flow_Mass1_47
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_47
# END
#
# BOUNDARY_CONDITION River_48
#   FLOW_CONDITION Flow_Mass1_48
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_48
# END
#
# BOUNDARY_CONDITION River_49
#   FLOW_CONDITION Flow_Mass1_49
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_49
# END
#
# BOUNDARY_CONDITION River_50
#   FLOW_CONDITION Flow_Mass1_50
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_50
# END
#
# BOUNDARY_CONDITION River_51
#   FLOW_CONDITION Flow_Mass1_51
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_51
# END
#
# BOUNDARY_CONDITION River_52
#   FLOW_CONDITION Flow_Mass1_52
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_52
# END
#
# BOUNDARY_CONDITION River_53
#   FLOW_CONDITION Flow_Mass1_53
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_53
# END
#
# BOUNDARY_CONDITION River_54
#   FLOW_CONDITION Flow_Mass1_54
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_54
# END
#
# BOUNDARY_CONDITION River_55
#   FLOW_CONDITION Flow_Mass1_55
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_55
# END
#
# BOUNDARY_CONDITION River_56
#   FLOW_CONDITION Flow_Mass1_56
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_56
# END
#
# BOUNDARY_CONDITION River_57
#   FLOW_CONDITION Flow_Mass1_57
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_57
# END
#
# BOUNDARY_CONDITION River_58
#   FLOW_CONDITION Flow_Mass1_58
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_58
# END
#
# BOUNDARY_CONDITION River_59
#   FLOW_CONDITION Flow_Mass1_59
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_59
# END
#
# BOUNDARY_CONDITION River_60
#   FLOW_CONDITION Flow_Mass1_60
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_60
# END
#
# BOUNDARY_CONDITION River_61
#   FLOW_CONDITION Flow_Mass1_61
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_61
# END
#
# BOUNDARY_CONDITION River_62
#   FLOW_CONDITION Flow_Mass1_62
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_62
# END
#
# BOUNDARY_CONDITION River_63
#   FLOW_CONDITION Flow_Mass1_63
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_63
# END
#
# BOUNDARY_CONDITION River_64
#   FLOW_CONDITION Flow_Mass1_64
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_64
# END
#
# BOUNDARY_CONDITION River_65
#   FLOW_CONDITION Flow_Mass1_65
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_65
# END
#
# BOUNDARY_CONDITION River_66
#   FLOW_CONDITION Flow_Mass1_66
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_66
# END
#
# BOUNDARY_CONDITION River_67
#   FLOW_CONDITION Flow_Mass1_67
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_67
# END
#
# BOUNDARY_CONDITION River_68
#   FLOW_CONDITION Flow_Mass1_68
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_68
# END
#
# BOUNDARY_CONDITION River_69
#   FLOW_CONDITION Flow_Mass1_69
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_69
# END
#
# BOUNDARY_CONDITION River_70
#   FLOW_CONDITION Flow_Mass1_70
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_70
# END
#
# BOUNDARY_CONDITION River_71
#   FLOW_CONDITION Flow_Mass1_71
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_71
# END
#
# BOUNDARY_CONDITION River_72
#   FLOW_CONDITION Flow_Mass1_72
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_72
# END
#
# BOUNDARY_CONDITION River_73
#   FLOW_CONDITION Flow_Mass1_73
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_73
# END
#
# BOUNDARY_CONDITION River_74
#   FLOW_CONDITION Flow_Mass1_74
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_74
# END
#
# BOUNDARY_CONDITION River_75
#   FLOW_CONDITION Flow_Mass1_75
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_75
# END
#
# BOUNDARY_CONDITION River_76
#   FLOW_CONDITION Flow_Mass1_76
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_76
# END
#
# BOUNDARY_CONDITION River_77
#   FLOW_CONDITION Flow_Mass1_77
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_77
# END
#
# BOUNDARY_CONDITION River_78
#   FLOW_CONDITION Flow_Mass1_78
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_78
# END
#
# BOUNDARY_CONDITION River_79
#   FLOW_CONDITION Flow_Mass1_79
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_79
# END
#
# BOUNDARY_CONDITION River_80
#   FLOW_CONDITION Flow_Mass1_80
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_80
# END
#
# BOUNDARY_CONDITION River_81
#   FLOW_CONDITION Flow_Mass1_81
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_81
# END
#
# BOUNDARY_CONDITION River_82
#   FLOW_CONDITION Flow_Mass1_82
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_82
# END
#
# BOUNDARY_CONDITION River_83
#   FLOW_CONDITION Flow_Mass1_83
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_83
# END
#
# BOUNDARY_CONDITION River_84
#   FLOW_CONDITION Flow_Mass1_84
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_84
# END
#
# BOUNDARY_CONDITION River_85
#   FLOW_CONDITION Flow_Mass1_85
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_85
# END
#
# BOUNDARY_CONDITION River_86
#   FLOW_CONDITION Flow_Mass1_86
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_86
# END
#
# BOUNDARY_CONDITION River_87
#   FLOW_CONDITION Flow_Mass1_87
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_87
# END
#
# BOUNDARY_CONDITION River_88
#   FLOW_CONDITION Flow_Mass1_88
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_88
# END
#
# BOUNDARY_CONDITION River_89
#   FLOW_CONDITION Flow_Mass1_89
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_89
# END
#
# BOUNDARY_CONDITION River_90
#   FLOW_CONDITION Flow_Mass1_90
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_90
# END
#
# BOUNDARY_CONDITION River_91
#   FLOW_CONDITION Flow_Mass1_91
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_91
# END
#
# BOUNDARY_CONDITION River_92
#   FLOW_CONDITION Flow_Mass1_92
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_92
# END
#
# BOUNDARY_CONDITION River_93
#   FLOW_CONDITION Flow_Mass1_93
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_93
# END
#
# BOUNDARY_CONDITION River_94
#   FLOW_CONDITION Flow_Mass1_94
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_94
# END
#
# BOUNDARY_CONDITION River_95
#   FLOW_CONDITION Flow_Mass1_95
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_95
# END
#
# BOUNDARY_CONDITION River_96
#   FLOW_CONDITION Flow_Mass1_96
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_96
# END
#
# BOUNDARY_CONDITION River_97
#   FLOW_CONDITION Flow_Mass1_97
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_97
# END
#
# BOUNDARY_CONDITION River_98
#   FLOW_CONDITION Flow_Mass1_98
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_98
# END
#
# BOUNDARY_CONDITION River_99
#   FLOW_CONDITION Flow_Mass1_99
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_99
# END
#
# BOUNDARY_CONDITION River_100
#   FLOW_CONDITION Flow_Mass1_100
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_100
# END
#
# BOUNDARY_CONDITION River_101
#   FLOW_CONDITION Flow_Mass1_101
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_101
# END
#
# BOUNDARY_CONDITION River_102
#   FLOW_CONDITION Flow_Mass1_102
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_102
# END
#
# BOUNDARY_CONDITION River_103
#   FLOW_CONDITION Flow_Mass1_103
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_103
# END
#
# BOUNDARY_CONDITION River_104
#   FLOW_CONDITION Flow_Mass1_104
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_104
# END
#
# BOUNDARY_CONDITION River_105
#   FLOW_CONDITION Flow_Mass1_105
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_105
# END
#
# BOUNDARY_CONDITION River_106
#   FLOW_CONDITION Flow_Mass1_106
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_106
# END
#
# BOUNDARY_CONDITION River_107
#   FLOW_CONDITION Flow_Mass1_107
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_107
# END
#
# BOUNDARY_CONDITION River_108
#   FLOW_CONDITION Flow_Mass1_108
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_108
# END
#
# BOUNDARY_CONDITION River_109
#   FLOW_CONDITION Flow_Mass1_109
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_109
# END
#
# BOUNDARY_CONDITION River_110
#   FLOW_CONDITION Flow_Mass1_110
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_110
# END
#
# BOUNDARY_CONDITION River_111
#   FLOW_CONDITION Flow_Mass1_111
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_111
# END
#
# BOUNDARY_CONDITION River_112
#   FLOW_CONDITION Flow_Mass1_112
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_112
# END
#
# BOUNDARY_CONDITION River_113
#   FLOW_CONDITION Flow_Mass1_113
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_113
# END
#
# BOUNDARY_CONDITION River_114
#   FLOW_CONDITION Flow_Mass1_114
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_114
# END
#
# BOUNDARY_CONDITION River_115
#   FLOW_CONDITION Flow_Mass1_115
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_115
# END
#
# BOUNDARY_CONDITION River_116
#   FLOW_CONDITION Flow_Mass1_116
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_116
# END
#
# BOUNDARY_CONDITION River_117
#   FLOW_CONDITION Flow_Mass1_117
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_117
# END
#
# BOUNDARY_CONDITION River_118
#   FLOW_CONDITION Flow_Mass1_118
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_118
# END
#
# BOUNDARY_CONDITION River_119
#   FLOW_CONDITION Flow_Mass1_119
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_119
# END
#
# BOUNDARY_CONDITION River_120
#   FLOW_CONDITION Flow_Mass1_120
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_120
# END
#
# BOUNDARY_CONDITION River_121
#   FLOW_CONDITION Flow_Mass1_121
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_121
# END
#
# BOUNDARY_CONDITION River_122
#   FLOW_CONDITION Flow_Mass1_122
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_122
# END
#
# BOUNDARY_CONDITION River_123
#   FLOW_CONDITION Flow_Mass1_123
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_123
# END
#
# BOUNDARY_CONDITION River_124
#   FLOW_CONDITION Flow_Mass1_124
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_124
# END
#
# BOUNDARY_CONDITION River_125
#   FLOW_CONDITION Flow_Mass1_125
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_125
# END
#
# BOUNDARY_CONDITION River_126
#   FLOW_CONDITION Flow_Mass1_126
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_126
# END
#
# BOUNDARY_CONDITION River_127
#   FLOW_CONDITION Flow_Mass1_127
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_127
# END
#
# BOUNDARY_CONDITION River_128
#   FLOW_CONDITION Flow_Mass1_128
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_128
# END
#
# BOUNDARY_CONDITION River_129
#   FLOW_CONDITION Flow_Mass1_129
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_129
# END
#
# BOUNDARY_CONDITION River_130
#   FLOW_CONDITION Flow_Mass1_130
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_130
# END
#
# BOUNDARY_CONDITION River_131
#   FLOW_CONDITION Flow_Mass1_131
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_131
# END
#
# BOUNDARY_CONDITION River_132
#   FLOW_CONDITION Flow_Mass1_132
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_132
# END
#
# BOUNDARY_CONDITION River_133
#   FLOW_CONDITION Flow_Mass1_133
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_133
# END
#
# BOUNDARY_CONDITION River_134
#   FLOW_CONDITION Flow_Mass1_134
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_134
# END
#
# BOUNDARY_CONDITION River_135
#   FLOW_CONDITION Flow_Mass1_135
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_135
# END
#
# BOUNDARY_CONDITION River_136
#   FLOW_CONDITION Flow_Mass1_136
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_136
# END
#
# BOUNDARY_CONDITION River_137
#   FLOW_CONDITION Flow_Mass1_137
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_137
# END
#
# BOUNDARY_CONDITION River_138
#   FLOW_CONDITION Flow_Mass1_138
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_138
# END
#
# BOUNDARY_CONDITION River_139
#   FLOW_CONDITION Flow_Mass1_139
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_139
# END
#
# BOUNDARY_CONDITION River_140
#   FLOW_CONDITION Flow_Mass1_140
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_140
# END
#
# BOUNDARY_CONDITION River_141
#   FLOW_CONDITION Flow_Mass1_141
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_141
# END
#
# BOUNDARY_CONDITION River_142
#   FLOW_CONDITION Flow_Mass1_142
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_142
# END
#
# BOUNDARY_CONDITION River_143
#   FLOW_CONDITION Flow_Mass1_143
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_143
# END
#
# BOUNDARY_CONDITION River_144
#   FLOW_CONDITION Flow_Mass1_144
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_144
# END
#
# BOUNDARY_CONDITION River_145
#   FLOW_CONDITION Flow_Mass1_145
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_145
# END
#
# BOUNDARY_CONDITION River_146
#   FLOW_CONDITION Flow_Mass1_146
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_146
# END
#
# BOUNDARY_CONDITION River_147
#   FLOW_CONDITION Flow_Mass1_147
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_147
# END
#
# BOUNDARY_CONDITION River_148
#   FLOW_CONDITION Flow_Mass1_148
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_148
# END
#
# BOUNDARY_CONDITION River_149
#   FLOW_CONDITION Flow_Mass1_149
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_149
# END
#
# BOUNDARY_CONDITION River_150
#   FLOW_CONDITION Flow_Mass1_150
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_150
# END
#
# BOUNDARY_CONDITION River_151
#   FLOW_CONDITION Flow_Mass1_151
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_151
# END
#
# BOUNDARY_CONDITION River_152
#   FLOW_CONDITION Flow_Mass1_152
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_152
# END
#
# BOUNDARY_CONDITION River_153
#   FLOW_CONDITION Flow_Mass1_153
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_153
# END
#
# BOUNDARY_CONDITION River_154
#   FLOW_CONDITION Flow_Mass1_154
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_154
# END
#
# BOUNDARY_CONDITION River_155
#   FLOW_CONDITION Flow_Mass1_155
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_155
# END
#
# BOUNDARY_CONDITION River_156
#   FLOW_CONDITION Flow_Mass1_156
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_156
# END
#
# BOUNDARY_CONDITION River_157
#   FLOW_CONDITION Flow_Mass1_157
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_157
# END
#
# BOUNDARY_CONDITION River_158
#   FLOW_CONDITION Flow_Mass1_158
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_158
# END
#
# BOUNDARY_CONDITION River_159
#   FLOW_CONDITION Flow_Mass1_159
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_159
# END
#
# BOUNDARY_CONDITION River_160
#   FLOW_CONDITION Flow_Mass1_160
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_160
# END
#
# BOUNDARY_CONDITION River_161
#   FLOW_CONDITION Flow_Mass1_161
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_161
# END
#
# BOUNDARY_CONDITION River_162
#   FLOW_CONDITION Flow_Mass1_162
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_162
# END
#
# BOUNDARY_CONDITION River_163
#   FLOW_CONDITION Flow_Mass1_163
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_163
# END
#
# BOUNDARY_CONDITION River_164
#   FLOW_CONDITION Flow_Mass1_164
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_164
# END
#
# BOUNDARY_CONDITION River_165
#   FLOW_CONDITION Flow_Mass1_165
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_165
# END
#
# BOUNDARY_CONDITION River_166
#   FLOW_CONDITION Flow_Mass1_166
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_166
# END
#
# BOUNDARY_CONDITION River_167
#   FLOW_CONDITION Flow_Mass1_167
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_167
# END
#
# BOUNDARY_CONDITION River_168
#   FLOW_CONDITION Flow_Mass1_168
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_168
# END
#
# BOUNDARY_CONDITION River_169
#   FLOW_CONDITION Flow_Mass1_169
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_169
# END
#
# BOUNDARY_CONDITION River_170
#   FLOW_CONDITION Flow_Mass1_170
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_170
# END
#
# BOUNDARY_CONDITION River_171
#   FLOW_CONDITION Flow_Mass1_171
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_171
# END
#
# BOUNDARY_CONDITION River_172
#   FLOW_CONDITION Flow_Mass1_172
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_172
# END
#
# BOUNDARY_CONDITION River_173
#   FLOW_CONDITION Flow_Mass1_173
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_173
# END
#
# BOUNDARY_CONDITION River_174
#   FLOW_CONDITION Flow_Mass1_174
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_174
# END
#
# BOUNDARY_CONDITION River_175
#   FLOW_CONDITION Flow_Mass1_175
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_175
# END
#
# BOUNDARY_CONDITION River_176
#   FLOW_CONDITION Flow_Mass1_176
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_176
# END
#
# BOUNDARY_CONDITION River_177
#   FLOW_CONDITION Flow_Mass1_177
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_177
# END
#
# BOUNDARY_CONDITION River_178
#   FLOW_CONDITION Flow_Mass1_178
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_178
# END
#
# BOUNDARY_CONDITION River_179
#   FLOW_CONDITION Flow_Mass1_179
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_179
# END
#
# BOUNDARY_CONDITION River_180
#   FLOW_CONDITION Flow_Mass1_180
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_180
# END
#
# BOUNDARY_CONDITION River_181
#   FLOW_CONDITION Flow_Mass1_181
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_181
# END
#
# BOUNDARY_CONDITION River_182
#   FLOW_CONDITION Flow_Mass1_182
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_182
# END
#
# BOUNDARY_CONDITION River_183
#   FLOW_CONDITION Flow_Mass1_183
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_183
# END
#
# BOUNDARY_CONDITION River_184
#   FLOW_CONDITION Flow_Mass1_184
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_184
# END
#
# BOUNDARY_CONDITION River_185
#   FLOW_CONDITION Flow_Mass1_185
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_185
# END
#
# BOUNDARY_CONDITION River_186
#   FLOW_CONDITION Flow_Mass1_186
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_186
# END
#
# BOUNDARY_CONDITION River_187
#   FLOW_CONDITION Flow_Mass1_187
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_187
# END
#
# BOUNDARY_CONDITION River_188
#   FLOW_CONDITION Flow_Mass1_188
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_188
# END
#
# BOUNDARY_CONDITION River_189
#   FLOW_CONDITION Flow_Mass1_189
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_189
# END
#
# BOUNDARY_CONDITION River_190
#   FLOW_CONDITION Flow_Mass1_190
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_190
# END
#
# BOUNDARY_CONDITION River_191
#   FLOW_CONDITION Flow_Mass1_191
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_191
# END
#
# BOUNDARY_CONDITION River_192
#   FLOW_CONDITION Flow_Mass1_192
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_192
# END
#
# BOUNDARY_CONDITION River_193
#   FLOW_CONDITION Flow_Mass1_193
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_193
# END
#
# BOUNDARY_CONDITION River_194
#   FLOW_CONDITION Flow_Mass1_194
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_194
# END
#
# BOUNDARY_CONDITION River_195
#   FLOW_CONDITION Flow_Mass1_195
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_195
# END
#
# BOUNDARY_CONDITION River_196
#   FLOW_CONDITION Flow_Mass1_196
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_196
# END
#
# BOUNDARY_CONDITION River_197
#   FLOW_CONDITION Flow_Mass1_197
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_197
# END
#
# BOUNDARY_CONDITION River_198
#   FLOW_CONDITION Flow_Mass1_198
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_198
# END
#
# BOUNDARY_CONDITION River_199
#   FLOW_CONDITION Flow_Mass1_199
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_199
# END
#
# BOUNDARY_CONDITION River_200
#   FLOW_CONDITION Flow_Mass1_200
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_200
# END
#
# BOUNDARY_CONDITION River_201
#   FLOW_CONDITION Flow_Mass1_201
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_201
# END
#
# BOUNDARY_CONDITION River_202
#   FLOW_CONDITION Flow_Mass1_202
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_202
# END
#
# BOUNDARY_CONDITION River_203
#   FLOW_CONDITION Flow_Mass1_203
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_203
# END
#
# BOUNDARY_CONDITION River_204
#   FLOW_CONDITION Flow_Mass1_204
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_204
# END
#
# BOUNDARY_CONDITION River_205
#   FLOW_CONDITION Flow_Mass1_205
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_205
# END
#
# BOUNDARY_CONDITION River_206
#   FLOW_CONDITION Flow_Mass1_206
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_206
# END
#
# BOUNDARY_CONDITION River_207
#   FLOW_CONDITION Flow_Mass1_207
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_207
# END
#
# BOUNDARY_CONDITION River_208
#   FLOW_CONDITION Flow_Mass1_208
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_208
# END
#
# BOUNDARY_CONDITION River_209
#   FLOW_CONDITION Flow_Mass1_209
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_209
# END
#
# BOUNDARY_CONDITION River_210
#   FLOW_CONDITION Flow_Mass1_210
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_210
# END
#
# BOUNDARY_CONDITION River_211
#   FLOW_CONDITION Flow_Mass1_211
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_211
# END
#
# BOUNDARY_CONDITION River_212
#   FLOW_CONDITION Flow_Mass1_212
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_212
# END
#
# BOUNDARY_CONDITION River_213
#   FLOW_CONDITION Flow_Mass1_213
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_213
# END
#
# BOUNDARY_CONDITION River_214
#   FLOW_CONDITION Flow_Mass1_214
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_214
# END
#
# BOUNDARY_CONDITION River_215
#   FLOW_CONDITION Flow_Mass1_215
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_215
# END
#
# BOUNDARY_CONDITION River_216
#   FLOW_CONDITION Flow_Mass1_216
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_216
# END
#
# BOUNDARY_CONDITION River_217
#   FLOW_CONDITION Flow_Mass1_217
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_217
# END
#
# BOUNDARY_CONDITION River_218
#   FLOW_CONDITION Flow_Mass1_218
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_218
# END
#
# BOUNDARY_CONDITION River_219
#   FLOW_CONDITION Flow_Mass1_219
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_219
# END
#
# BOUNDARY_CONDITION River_220
#   FLOW_CONDITION Flow_Mass1_220
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_220
# END
#
# BOUNDARY_CONDITION River_221
#   FLOW_CONDITION Flow_Mass1_221
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_221
# END
#
# BOUNDARY_CONDITION River_222
#   FLOW_CONDITION Flow_Mass1_222
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_222
# END
#
# BOUNDARY_CONDITION River_223
#   FLOW_CONDITION Flow_Mass1_223
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_223
# END
#
# BOUNDARY_CONDITION River_224
#   FLOW_CONDITION Flow_Mass1_224
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_224
# END
#
# BOUNDARY_CONDITION River_225
#   FLOW_CONDITION Flow_Mass1_225
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_225
# END
#
# BOUNDARY_CONDITION River_226
#   FLOW_CONDITION Flow_Mass1_226
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_226
# END
#
# BOUNDARY_CONDITION River_227
#   FLOW_CONDITION Flow_Mass1_227
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_227
# END
#
# BOUNDARY_CONDITION River_228
#   FLOW_CONDITION Flow_Mass1_228
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_228
# END
#
# BOUNDARY_CONDITION River_229
#   FLOW_CONDITION Flow_Mass1_229
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_229
# END
#
# BOUNDARY_CONDITION River_230
#   FLOW_CONDITION Flow_Mass1_230
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_230
# END
#
# BOUNDARY_CONDITION River_231
#   FLOW_CONDITION Flow_Mass1_231
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_231
# END
#
# BOUNDARY_CONDITION River_232
#   FLOW_CONDITION Flow_Mass1_232
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_232
# END
#
# BOUNDARY_CONDITION River_233
#   FLOW_CONDITION Flow_Mass1_233
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_233
# END
#
# BOUNDARY_CONDITION River_234
#   FLOW_CONDITION Flow_Mass1_234
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_234
# END
#
# BOUNDARY_CONDITION River_235
#   FLOW_CONDITION Flow_Mass1_235
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_235
# END
#
# BOUNDARY_CONDITION River_236
#   FLOW_CONDITION Flow_Mass1_236
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_236
# END
#
# BOUNDARY_CONDITION River_237
#   FLOW_CONDITION Flow_Mass1_237
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_237
# END
#
# BOUNDARY_CONDITION River_238
#   FLOW_CONDITION Flow_Mass1_238
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_238
# END
#
# BOUNDARY_CONDITION River_239
#   FLOW_CONDITION Flow_Mass1_239
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_239
# END
#
# BOUNDARY_CONDITION River_240
#   FLOW_CONDITION Flow_Mass1_240
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_240
# END
#
# BOUNDARY_CONDITION River_241
#   FLOW_CONDITION Flow_Mass1_241
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_241
# END
#
# BOUNDARY_CONDITION River_242
#   FLOW_CONDITION Flow_Mass1_242
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_242
# END
#
# BOUNDARY_CONDITION River_243
#   FLOW_CONDITION Flow_Mass1_243
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_243
# END
#
# BOUNDARY_CONDITION River_244
#   FLOW_CONDITION Flow_Mass1_244
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_244
# END
#
# BOUNDARY_CONDITION River_245
#   FLOW_CONDITION Flow_Mass1_245
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_245
# END
#
# BOUNDARY_CONDITION River_246
#   FLOW_CONDITION Flow_Mass1_246
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_246
# END
#
# BOUNDARY_CONDITION River_247
#   FLOW_CONDITION Flow_Mass1_247
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_247
# END
#
# BOUNDARY_CONDITION River_248
#   FLOW_CONDITION Flow_Mass1_248
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_248
# END
#
# BOUNDARY_CONDITION River_249
#   FLOW_CONDITION Flow_Mass1_249
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_249
# END
#
# BOUNDARY_CONDITION River_250
#   FLOW_CONDITION Flow_Mass1_250
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_250
# END
#
# BOUNDARY_CONDITION River_251
#   FLOW_CONDITION Flow_Mass1_251
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_251
# END
#
# BOUNDARY_CONDITION River_252
#   FLOW_CONDITION Flow_Mass1_252
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_252
# END
#
# BOUNDARY_CONDITION River_253
#   FLOW_CONDITION Flow_Mass1_253
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_253
# END
#
# BOUNDARY_CONDITION River_254
#   FLOW_CONDITION Flow_Mass1_254
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_254
# END
#
# BOUNDARY_CONDITION River_255
#   FLOW_CONDITION Flow_Mass1_255
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_255
# END
#
# BOUNDARY_CONDITION River_256
#   FLOW_CONDITION Flow_Mass1_256
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_256
# END
#
# BOUNDARY_CONDITION River_257
#   FLOW_CONDITION Flow_Mass1_257
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_257
# END
#
# BOUNDARY_CONDITION River_258
#   FLOW_CONDITION Flow_Mass1_258
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_258
# END
#
# BOUNDARY_CONDITION River_259
#   FLOW_CONDITION Flow_Mass1_259
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_259
# END
#
# BOUNDARY_CONDITION River_260
#   FLOW_CONDITION Flow_Mass1_260
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_260
# END
#
# BOUNDARY_CONDITION River_261
#   FLOW_CONDITION Flow_Mass1_261
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_261
# END
#
# BOUNDARY_CONDITION River_262
#   FLOW_CONDITION Flow_Mass1_262
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_262
# END
#
# BOUNDARY_CONDITION River_263
#   FLOW_CONDITION Flow_Mass1_263
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_263
# END
#
# BOUNDARY_CONDITION River_264
#   FLOW_CONDITION Flow_Mass1_264
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_264
# END
#
# BOUNDARY_CONDITION River_265
#   FLOW_CONDITION Flow_Mass1_265
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_265
# END
#
# BOUNDARY_CONDITION River_266
#   FLOW_CONDITION Flow_Mass1_266
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_266
# END
#
# BOUNDARY_CONDITION River_267
#   FLOW_CONDITION Flow_Mass1_267
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_267
# END
#
# BOUNDARY_CONDITION River_268
#   FLOW_CONDITION Flow_Mass1_268
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_268
# END
#
# BOUNDARY_CONDITION River_269
#   FLOW_CONDITION Flow_Mass1_269
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_269
# END
#
# BOUNDARY_CONDITION River_270
#   FLOW_CONDITION Flow_Mass1_270
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_270
# END
#
# BOUNDARY_CONDITION River_271
#   FLOW_CONDITION Flow_Mass1_271
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_271
# END
#
# BOUNDARY_CONDITION River_272
#   FLOW_CONDITION Flow_Mass1_272
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_272
# END
#
# BOUNDARY_CONDITION River_273
#   FLOW_CONDITION Flow_Mass1_273
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_273
# END
#
# BOUNDARY_CONDITION River_274
#   FLOW_CONDITION Flow_Mass1_274
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_274
# END
#
# BOUNDARY_CONDITION River_275
#   FLOW_CONDITION Flow_Mass1_275
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_275
# END
#
# BOUNDARY_CONDITION River_276
#   FLOW_CONDITION Flow_Mass1_276
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_276
# END
#
# BOUNDARY_CONDITION River_277
#   FLOW_CONDITION Flow_Mass1_277
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_277
# END
#
# BOUNDARY_CONDITION River_278
#   FLOW_CONDITION Flow_Mass1_278
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_278
# END
#
# BOUNDARY_CONDITION River_279
#   FLOW_CONDITION Flow_Mass1_279
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_279
# END
#
# BOUNDARY_CONDITION River_280
#   FLOW_CONDITION Flow_Mass1_280
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_280
# END
#
# BOUNDARY_CONDITION River_281
#   FLOW_CONDITION Flow_Mass1_281
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_281
# END
#
# BOUNDARY_CONDITION River_282
#   FLOW_CONDITION Flow_Mass1_282
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_282
# END
#
# BOUNDARY_CONDITION River_283
#   FLOW_CONDITION Flow_Mass1_283
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_283
# END
#
# BOUNDARY_CONDITION River_284
#   FLOW_CONDITION Flow_Mass1_284
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_284
# END
#
# BOUNDARY_CONDITION River_285
#   FLOW_CONDITION Flow_Mass1_285
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_285
# END
#
# BOUNDARY_CONDITION River_286
#   FLOW_CONDITION Flow_Mass1_286
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_286
# END
#
# BOUNDARY_CONDITION River_287
#   FLOW_CONDITION Flow_Mass1_287
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_287
# END
#
# BOUNDARY_CONDITION River_288
#   FLOW_CONDITION Flow_Mass1_288
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_288
# END
#
# BOUNDARY_CONDITION River_289
#   FLOW_CONDITION Flow_Mass1_289
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_289
# END
#
# BOUNDARY_CONDITION River_290
#   FLOW_CONDITION Flow_Mass1_290
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_290
# END
#
# BOUNDARY_CONDITION River_291
#   FLOW_CONDITION Flow_Mass1_291
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_291
# END
#
# BOUNDARY_CONDITION River_292
#   FLOW_CONDITION Flow_Mass1_292
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_292
# END
#
# BOUNDARY_CONDITION River_293
#   FLOW_CONDITION Flow_Mass1_293
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_293
# END
#
# BOUNDARY_CONDITION River_294
#   FLOW_CONDITION Flow_Mass1_294
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_294
# END
#
# BOUNDARY_CONDITION River_295
#   FLOW_CONDITION Flow_Mass1_295
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_295
# END
#
# BOUNDARY_CONDITION River_296
#   FLOW_CONDITION Flow_Mass1_296
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_296
# END
#
# BOUNDARY_CONDITION River_297
#   FLOW_CONDITION Flow_Mass1_297
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_297
# END
#
# BOUNDARY_CONDITION River_298
#   FLOW_CONDITION Flow_Mass1_298
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_298
# END
#
# BOUNDARY_CONDITION River_299
#   FLOW_CONDITION Flow_Mass1_299
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_299
# END
#
# BOUNDARY_CONDITION River_300
#   FLOW_CONDITION Flow_Mass1_300
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_300
# END
#
# BOUNDARY_CONDITION River_301
#   FLOW_CONDITION Flow_Mass1_301
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_301
# END
#
# BOUNDARY_CONDITION River_302
#   FLOW_CONDITION Flow_Mass1_302
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_302
# END
#
# BOUNDARY_CONDITION River_303
#   FLOW_CONDITION Flow_Mass1_303
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_303
# END
#
# BOUNDARY_CONDITION River_304
#   FLOW_CONDITION Flow_Mass1_304
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_304
# END
#
# BOUNDARY_CONDITION River_305
#   FLOW_CONDITION Flow_Mass1_305
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_305
# END
#
# BOUNDARY_CONDITION River_306
#   FLOW_CONDITION Flow_Mass1_306
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_306
# END
#
# BOUNDARY_CONDITION River_307
#   FLOW_CONDITION Flow_Mass1_307
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_307
# END
#
# BOUNDARY_CONDITION River_308
#   FLOW_CONDITION Flow_Mass1_308
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_308
# END
#
# BOUNDARY_CONDITION River_309
#   FLOW_CONDITION Flow_Mass1_309
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_309
# END
#
# BOUNDARY_CONDITION River_310
#   FLOW_CONDITION Flow_Mass1_310
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_310
# END
#
# BOUNDARY_CONDITION River_311
#   FLOW_CONDITION Flow_Mass1_311
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_311
# END
#
# BOUNDARY_CONDITION River_312
#   FLOW_CONDITION Flow_Mass1_312
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_312
# END
#
# BOUNDARY_CONDITION River_313
#   FLOW_CONDITION Flow_Mass1_313
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_313
# END
#
# BOUNDARY_CONDITION River_314
#   FLOW_CONDITION Flow_Mass1_314
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_314
# END
#
# BOUNDARY_CONDITION River_315
#   FLOW_CONDITION Flow_Mass1_315
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_315
# END
#
# BOUNDARY_CONDITION River_316
#   FLOW_CONDITION Flow_Mass1_316
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_316
# END
#
# BOUNDARY_CONDITION River_317
#   FLOW_CONDITION Flow_Mass1_317
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_317
# END
#
# BOUNDARY_CONDITION River_318
#   FLOW_CONDITION Flow_Mass1_318
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_318
# END
#
# BOUNDARY_CONDITION River_319
#   FLOW_CONDITION Flow_Mass1_319
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_319
# END
#
# BOUNDARY_CONDITION River_320
#   FLOW_CONDITION Flow_Mass1_320
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_320
# END
#
# BOUNDARY_CONDITION River_321
#   FLOW_CONDITION Flow_Mass1_321
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_321
# END
#
# BOUNDARY_CONDITION River_322
#   FLOW_CONDITION Flow_Mass1_322
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_322
# END
#
# BOUNDARY_CONDITION River_323
#   FLOW_CONDITION Flow_Mass1_323
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_323
# END
#
# BOUNDARY_CONDITION River_324
#   FLOW_CONDITION Flow_Mass1_324
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_324
# END
#
# BOUNDARY_CONDITION River_325
#   FLOW_CONDITION Flow_Mass1_325
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_325
# END
#
# BOUNDARY_CONDITION River_326
#   FLOW_CONDITION Flow_Mass1_326
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_326
# END
#
# BOUNDARY_CONDITION River_327
#   FLOW_CONDITION Flow_Mass1_327
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_327
# END
#
# BOUNDARY_CONDITION River_328
#   FLOW_CONDITION Flow_Mass1_328
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_328
# END
#
# BOUNDARY_CONDITION River_329
#   FLOW_CONDITION Flow_Mass1_329
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_329
# END
#
# BOUNDARY_CONDITION River_330
#   FLOW_CONDITION Flow_Mass1_330
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_330
# END
#
# BOUNDARY_CONDITION River_331
#   FLOW_CONDITION Flow_Mass1_331
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_331
# END
#
# BOUNDARY_CONDITION River_332
#   FLOW_CONDITION Flow_Mass1_332
#   TRANSPORT_CONDITION Solute_river
#   REGION Mass1_332
# END

# %%
cat("#==================stratigraphy couplers=========================")
cat("\n")
cat("STRATA")
cat("\n")
cat(paste("  MATERIAL", fname_material.h5.in))
cat("\n")
cat("END")
cat("\n")
cat("\n")
# cat("#==================observation points=========================")
# cat('\n')
# # % putting in "observation points" in input deck
# for (iwell in well.list){
#   
#   if (screen_top[iwell] >= z0 & screen_bot[iwell] <= z0+zlen) {
#   z = cells_z[which(cells_z >= screen_bot[iwell] & (cells_z <= screen_top[iwell]))]
#   nz = length(z)
#   # wellname = rownames(Well)[iwell]
#     for (j in 1:nz){
#  
#       cat('OBSERVATION')
#       cat('\n')
#       cat(paste('  REGION ', iwell, '_', j, sep = ''))
#       cat('\n')
#       cat('  VELOCITY ')
#       cat('\n')
#       cat('/')
#       cat('\n')
#       cat('\n')
#     }
#   }
# }
# Out:
# #==================stratigraphy couplers=========================
# STRATA
#   MATERIAL HFR_material_river.h5
# END

# %%
cat("#==================END=========================")
cat("\n")
cat("END_SUBSURFACE")
sink()
# Out:
# #==================END=========================
# END_SUBSURFACE
