# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fname = '/Users/shua784/Dropbox/PNNL/Projects/Reach_scale_model/Outputs/hanford_thickness_profile.csv'
fig_dir = '/Users/shua784/Dropbox/PNNL/Projects/Reach_scale_model/manuscript/figures/'

# %%
df = pd.read_csv(fname)

# %%
# %matplotlib inline

fig,ax = plt.subplots(1,1)
df.plot(x='Hf_thickness', y='Distance', legend = False, ax=ax, color = 'black')

ax.set_xlim(0, 35)
ax.set_ylim(0, 73.5)

# fig.tight_layout()

fig.set_size_inches(3, 5)

# %%
fig.savefig(fig_dir + 'hf_profile.eps', transparent = True, dpi=300)
plt.close(fig)

# %%
df
# Out:
#      Mass1  Hf_thickness  Distance  riverkm
# 0       40          33.0    73.188  624.940
# 1       41          32.5    72.942  624.694
# 2       42          31.6    72.677  624.429
# 3       43          30.5    72.450  624.202
# 4       44          30.0    72.212  623.964
# 5       45          30.0    71.964  623.716
# 6       46          29.6    71.719  623.471
# 7       47          28.8    71.473  623.225
# 8       48          28.1    71.235  622.987
# 9       49          30.2    70.997  622.749
# 10      50          29.4    70.757  622.509
# 11      51          25.7    70.517  622.269
# 12      52          25.0    70.269  622.021
# 13      53          24.3    70.034  621.786
# 14      54          21.3    69.788  621.540
# 15      55          22.6    69.543  621.295
# 16      56          22.1    69.292  621.044
# 17      57          17.3    69.046  620.798
# 18      58          19.2    68.795  620.547
# 19      59          17.5    68.542  620.294
# ...
