# %% [markdown]
# # NERSC Tests
# This notebook will test out a few ideas. First is Juptyer Widgets

# %%
from ipyleaflet import Map
Map(center=[34.6252978589571, -77.34580993652344], zoom=10)
# Note this is currently problematic on NERSC

# %%
import ipywidgets as widgets

widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

# %% [markdown]
# http://nbconvert.readthedocs.io/en/latest/execute_api.html

# %% [markdown]
# Command to run notebooks on the commandline
# ```bash
# jupyter nbconvert --to notebook --execute mynotebook.ipynb
# ```

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(0,10))
plt.xlim(0,4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 4)

# %% [markdown]
# ## Paraview load state in Python
# https://www.paraview.org/Wiki/ParaView/Python/Loading_and_saving_state
#
# Save figure:
# https://stackoverflow.com/questions/27430588/paraview-python-command-to-save-picture-of-defined-size?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa
